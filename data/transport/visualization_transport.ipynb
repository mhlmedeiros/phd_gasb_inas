# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition, mark_inset)
import numpy as np

FONT_LABELS = 18
FONT_TITLES = 20
font = {'family' : 'serif', 'weight' : 'bold', 'size': FONT_LABELS}
matplotlib.rc('font', **font)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# %%
transport_file_0 = "data_435_440_meV_Fermi_Transport_Total_2001.npy"
fermi_energy_0   = "data_435_440_meV_Fermi_2001.npy"
trans_0  = np.load(transport_file_0)
energy_0 = np.load(fermi_energy_0)

transport_file_1 = "data_439.7_440_meV_Fermi_Transport_Total_1001.npy"
fermi_energy_1   = "data_439.7_440_meV_Fermi_1001.npy"
trans_1  = np.load(transport_file_1)
energy_1 = np.load(fermi_energy_1)

transport_file_2 = "data_439.7_440_meV_Fermi_Transport_Total_1001_L_707.1067811865476.npy"
fermi_energy_2   = "data_439.7_440_meV_Fermi_1001_L_707.1067811865476.npy"
trans_2  = np.load(transport_file_2)
energy_2 = np.load(fermi_energy_2)

transport_file_3 = "data_439.7_440_meV_Fermi_Transport_Total_1001_L_1000.npy"
fermi_energy_3   = "data_439.7_440_meV_Fermi_1001_L_1000.npy"
trans_3  = np.load(transport_file_3)
energy_3 = np.load(fermi_energy_3)

transport_file_4 = "data_439.5_440.5_meV_Fermi_Transport_Total_2001_L_299.99999999999994.npy"
fermi_energy_4   = "data_439.5_440.5_meV_Fermi_2001_L_299.99999999999994.npy"
trans_4  = np.load(transport_file_4)
energy_4 = np.load(fermi_energy_4)

transport_file_5 = "data_439.5_440.5_meV_Fermi_Transport_Total_2001_L_599.9999999999999.npy"
fermi_energy_5   = "data_439.5_440.5_meV_Fermi_2001_L_599.9999999999999.npy"
trans_5  = np.load(transport_file_5)
energy_5 = np.load(fermi_energy_5)

extrema_file_1 = "data_439.7_440_meV_Fermi_Transport_Total_1001_L_707.1067811865476_extrema_Fermi_439_440.npy"
extrema_file_fermi_energy_1 = "data_439.7_440_meV_Fermi_1001_L_707.1067811865476_extrema_Fermi_439_440.npy"
extrema_val_1  = np.load(extrema_file_1)
extrema_val_energy_1 = np.load(extrema_file_fermi_energy_1)

extrema_file_2 = "data_439.7_440_meV_Fermi_Transport_Total_1001_L_1000_extrema_Fermi_439_440.npy"
extrema_file_fermi_energy_2 = "data_439.7_440_meV_Fermi_1001_L_1000_extrema_Fermi_439_440.npy"
extrema_val_2  = np.load(extrema_file_2)
extrema_val_energy_2 = np.load(extrema_file_fermi_energy_2)

# %%
figure, ax1 = plt.subplots(figsize=(9,6))

# ax1.plot(energy_0, trans_0, 
#          #marker = 'o',
#          #markevery = 10,
#          linewidth = 2,
#          color = 'r',
#          label = r'$L = 500$ nm')

ax1.plot(energy_1, trans_1, 
         #marker = 'o',
         #markevery = 10,
         linewidth = 2,
#          color = 'r',
         label = r'$L = 500$ nm')

ax1.plot(energy_2, trans_2, 
         #marker = 's',
#          linestyle = '--',
         linewidth = 0.8,
#          color = 'b',
         #markevery = 10,
         label = r'$L = 500\sqrt{2}$ nm')

# ax1.plot(energy_3, trans_3, 
#          #marker = '^',
#          linestyle = '-.',
#          linewidth = 0.8,
#          color = 'g',
#          #markevery = 10, 
#          label = r'$L = 1~\mu$m')

ax1.plot(energy_4, trans_4, 
         #marker = 's',
#          linestyle = '--',
         linewidth = 0.8,
#          color = 'b',
         #markevery = 10,
         label = r'$L = 300$ nm')

ax1.plot(energy_5, trans_5, 
         #marker = '^',
#          linestyle = '-.',
         linewidth = 0.8,
#          color = 'g',
         #markevery = 10, 
         label = r'$L = 600$ nm')

# ax1.plot(extrema_val_energy_1, extrema_val_1, 
#          marker = '^',
#          linestyle = '',
# #          linewidth = 0.8,
#          color = 'b')
#          #markevery = 10, 
# #          label = r'$L = 500\sqrt{2}$ nm extr.')

# ax1.plot(extrema_val_energy_2, extrema_val_2, 
#          marker = '^',
#          linestyle = '',
# #          linewidth = 0.8,
#          color = 'g')
#          #markevery = 10, 
# #          label = r'$L = 1~\mu$m extr.')


ax1.legend()
ax1.set_xlim(440,439.7)
ax1.set_ylim(1.5,3.5)
ax1.set_xlabel("Fermi [meV]")
ax1.set_ylabel(r"$\sigma~[e^2/h]$")
plt.tight_layout()
plt.savefig("comparison_transport_length.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
transport_file_4 = "data_435_440_meV_Fermi_Transport_Total_2001.npy"
fermi_energy_4   = "data_435_440_meV_Fermi_2001.npy"
trans_4  = np.load(transport_file_4)
energy_4 = np.load(fermi_energy_4)

transport_file_5 = "data_440_435_meV_Fermi_Transport_Total_2001_L_707.1067811865476.npy"
fermi_energy_5   = "data_440_435_meV_Fermi_2001_L_707.1067811865476.npy"
trans_5  = np.load(transport_file_5)
energy_5 = np.load(fermi_energy_5)

# %%
figure, ax2 = plt.subplots(figsize=(9,5))

ax2.plot(energy_4, trans_4, marker = 'o', markevery = 10, label = r'$L = 500$ nm')
ax2.plot(energy_5, trans_5, marker = 's', markevery = 10, label = r'$L = 500\sqrt{2}$ nm')
# ax2.plot(energy_3, trans_3, marker = '^', markevery = 10, label = r'$L = 1~\mu$m')
ax2.legend()
ax2.set_xlim(440,438)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
transport_file_6 = "data_448_450.1_meV_Fermi_Transport_Total_2001.npy"
fermi_energy_6   = "data_448_450.1_meV_Fermi_2001.npy"
trans_6  = np.load(transport_file_6)
energy_6 = np.load(fermi_energy_6)

transport_file_7 = "data_448_450.1_meV_Fermi_Transport_Total_2001_L_707.1067811865476.npy"
fermi_energy_7   = "data_448_450.1_meV_Fermi_2001_L_707.1067811865476.npy"
trans_7  = np.load(transport_file_7)
energy_7 = np.load(fermi_energy_7)

transport_file_8 = "data_448_450.1_meV_Fermi_Transport_Total_2001_L_1000.0.npy"
fermi_energy_8   = "data_448_450.1_meV_Fermi_2001_L_1000.0.npy"
trans_8  = np.load(transport_file_8)
energy_8 = np.load(fermi_energy_8)

extrema_file_cond_1 = "data_448_450.1_meV_Fermi_Transport_Total_2001_L_1000.0_extrema_Fermi_448_450.npy"
fermi_extrema_file_cond_1 = "data_448_450.1_meV_Fermi_2001_L_1000.0_extrema_Fermi_448_450.npy"
extrema_cond_1  = np.load(extrema_file_cond_1)
fermi_extrema_cond_1 = np.load(fermi_extrema_file_cond_1)

extrema_file_cond_2 = "data_448_450.1_meV_Fermi_Transport_Total_2001_L_707.1067811865476_extrema_Fermi_448_450.npy"
fermi_extrema_file_cond_2 = "data_448_450.1_meV_Fermi_2001_L_707.1067811865476_extrema_Fermi_448_450.npy"
extrema_cond_2  = np.load(extrema_file_cond_2)
fermi_extrema_cond_2 = np.load(fermi_extrema_file_cond_2)

# %%
figure, ax3 = plt.subplots(figsize=(9,6))

ax3.plot(energy_6, trans_6, 
         #marker = 'o',
         #markevery = 10,
         linewidth = 2,
         color = 'r',
         label = r'$L = 500$ nm')
ax3.plot(energy_7, trans_7, 
         #marker = 's',
         linestyle = '--',
         linewidth = 0.8,
         color = 'b',
         #markevery = 10,
         label = r'$L = 500\sqrt{2}$ nm')
ax3.plot(energy_8, trans_8, 
         #marker = '^',
         linestyle = '-.',
         linewidth = 0.8,
         color = 'g',
         #markevery = 10, 
         label = r'$L = 1~\mu$m')
ax3.plot(fermi_extrema_cond_1, extrema_cond_1,
         marker = '^',
         linestyle = '',
#          linewidth = 0.8,
         color = 'g',
#          #markevery = 10, 
         label = r'$L = 1~\mu$m extr.')

ax3.plot(fermi_extrema_cond_2, extrema_cond_2,
         marker = '^',
         linestyle = '',
#          linewidth = 0.8,
         color = 'b',
#          #markevery = 10, 
         label = r'$L = 500\sqrt{2}$ nm extr.')

ax3.legend()
ax3.set_xlim(448.5,449.5)
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
x = np.array([1,2,3])

# %%
x
# Out:
# array([1, 2, 3])

# %%
reversed(x)
# Out:
# array([1, 2, 3])

# %%
x_complete_1 = np.load("data_439.5_449.5_meV_Fermi_2001_L_500.0.npy")
y_complete_1 = np.load("data_439.5_449.5_meV_Fermi_Transport_Total_2001_L_500.0.npy")

x_complete_2 = np.load("data_439.5_449.5_meV_Fermi_2001_L_299.99999999999994.npy")
y_complete_2 = np.load("data_439.5_449.5_meV_Fermi_Transport_Total_2001_L_299.99999999999994.npy")

fig, ax_complete = plt.subplots(figsize=(8,5))
ax_complete.plot(x_complete_1, y_complete_1)
ax_complete.plot(x_complete_2, y_complete_2)
ax_complete.set_xlabel("Fermi [meV]")
ax_complete.set_ylabel(r"$\sigma~[e^2/h]$")
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
bagunça = np.array([18,5,51,6,0,98])

# %%
bagunça.sort()

# %%
bagunça
# Out:
# array([ 0,  5,  6, 18, 51, 98])
